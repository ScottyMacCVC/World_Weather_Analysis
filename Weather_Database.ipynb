# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
city = citipy.nearest_city(49.4928, 117.2948)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d7bfa95e9bf349dc6d907ee3f1991927

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | souillac
# Processing Record 6 of Set 1 | chumikan
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | eureka
# Processing Record 9 of Set 1 | lata
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | san joaquin
# Processing Record 12 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 13 of Set 1 | tagum
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | sisimiut
# Processing Record 25 of Set 1 | college
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | moche
# Processing Record 28 of Set 1 | antigonish
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | duverge
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | bereznik
# Processing Record 34 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | lavrentiya
# Processing Record 37 of Set 1 | marawi
# Processing Record 38 of Set 1 | buala
# Processing Record 39 of Set 1 | luderitz
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | coihaique
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | kabare
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | namibe
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | arman
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | saint-ambroise
# Processing Record 5 of Set 2 | gabriel leyva solano
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | bathsheba
# Processing Record 8 of Set 2 | mitu
# Processing Record 9 of Set 2 | crixas
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | akyab
# Processing Record 12 of Set 2 | nouadhibou
# Processing Record 13 of Set 2 | mount gambier
# Processing Record 14 of Set 2 | itarema
# Processing Record 15 of Set 2 | hongjiang
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | lensk
# Processing Record 18 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | kanungu
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | daxian
# City not found. Skipping...
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | bay roberts
# Processing Record 28 of Set 2 | muros
# Processing Record 29 of Set 2 | hualmay
# Processing Record 30 of Set 2 | qarayeri
# Processing Record 31 of Set 2 | araouane
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | chernyshevskiy
# Processing Record 34 of Set 2 | havre-saint-pierre
# Processing Record 35 of Set 2 | gorontalo
# Processing Record 36 of Set 2 | hirata
# Processing Record 37 of Set 2 | port hedland
# Processing Record 38 of Set 2 | rio gallegos
# Processing Record 39 of Set 2 | changping
# Processing Record 40 of Set 2 | samarai
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | laguna
# Processing Record 44 of Set 2 | sarkand
# Processing Record 45 of Set 2 | tromso
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | alugan
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | limbang
# Processing Record 1 of Set 3 | vanimo
# Processing Record 2 of Set 3 | avera
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | tessalit
# Processing Record 5 of Set 3 | wewak
# Processing Record 6 of Set 3 | mount isa
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | kimbe
# Processing Record 9 of Set 3 | barhi
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | kattivakkam
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | manyana
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | maragheh
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | beloha
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | iquitos
# Processing Record 22 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | noumea
# Processing Record 25 of Set 3 | la rioja
# Processing Record 26 of Set 3 | claudio
# Processing Record 27 of Set 3 | fayaoue
# Processing Record 28 of Set 3 | prince rupert
# Processing Record 29 of Set 3 | roma
# Processing Record 30 of Set 3 | batagay-alyta
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | vila franca do campo
# Processing Record 33 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 3 | loandjili
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 3 | udachnyy
# Processing Record 38 of Set 3 | namatanai
# Processing Record 39 of Set 3 | acapulco
# Processing Record 40 of Set 3 | ulladulla
# Processing Record 41 of Set 3 | ahipara
# Processing Record 42 of Set 3 | svetlyy
# Processing Record 43 of Set 3 | visnes
# Processing Record 44 of Set 3 | santa cruz
# Processing Record 45 of Set 3 | juba
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | srednekolymsk
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | basco
# Processing Record 50 of Set 3 | atuona
# Processing Record 1 of Set 4 | iracoubo
# Processing Record 2 of Set 4 | svetlaya
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | lovozero
# Processing Record 5 of Set 4 | fare
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 4 | broome
# Processing Record 9 of Set 4 | san cristobal
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | bengkulu
# Processing Record 12 of Set 4 | saint-joseph
# Processing Record 13 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 4 | la romana
# Processing Record 15 of Set 4 | kaitangata
# Processing Record 16 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 4 | talas
# Processing Record 18 of Set 4 | vaini
# Processing Record 19 of Set 4 | xining
# Processing Record 20 of Set 4 | port blair
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | atbasar
# Processing Record 23 of Set 4 | nova olimpia
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | katsiveli
# City not found. Skipping...
# Processing Record 26 of Set 4 | beaverlodge
# Processing Record 27 of Set 4 | tiksi
# Processing Record 28 of Set 4 | belyy
# Processing Record 29 of Set 4 | bela
# Processing Record 30 of Set 4 | henties bay
# Processing Record 31 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | bridlington
# Processing Record 34 of Set 4 | shingu
# Processing Record 35 of Set 4 | saint-georges
# Processing Record 36 of Set 4 | erzin
# Processing Record 37 of Set 4 | sao filipe
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | sirvintos
# Processing Record 40 of Set 4 | morant bay
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | rodrigues alves
# Processing Record 43 of Set 4 | yaransk
# Processing Record 44 of Set 4 | khovu-aksy
# Processing Record 45 of Set 4 | sao gabriel da cachoeira
# Processing Record 46 of Set 4 | sisophon
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | suez
# Processing Record 49 of Set 4 | anchorage
# Processing Record 50 of Set 4 | santo antonio do ica
# Processing Record 1 of Set 5 | mokhsogollokh
# Processing Record 2 of Set 5 | sibolga
# Processing Record 3 of Set 5 | castanhal
# Processing Record 4 of Set 5 | barrow
# Processing Record 5 of Set 5 | hilo
# Processing Record 6 of Set 5 | seguela
# Processing Record 7 of Set 5 | cine
# Processing Record 8 of Set 5 | zhigansk
# Processing Record 9 of Set 5 | port elizabeth
# Processing Record 10 of Set 5 | moengo
# Processing Record 11 of Set 5 | taoudenni
# Processing Record 12 of Set 5 | itoman
# Processing Record 13 of Set 5 | mezen
# Processing Record 14 of Set 5 | ilhabela
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | lively
# Processing Record 17 of Set 5 | merauke
# Processing Record 18 of Set 5 | zyryanovsk
# Processing Record 19 of Set 5 | a
# City not found. Skipping...
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | tuatapere
# Processing Record 22 of Set 5 | vao
# Processing Record 23 of Set 5 | kolpashevo
# Processing Record 24 of Set 5 | tura
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | deputatskiy
# Processing Record 27 of Set 5 | chichibu
# Processing Record 28 of Set 5 | aasiaat
# Processing Record 29 of Set 5 | valparaiso
# Processing Record 30 of Set 5 | abu kamal
# Processing Record 31 of Set 5 | dafeng
# Processing Record 32 of Set 5 | hovd
# Processing Record 33 of Set 5 | nanakuli
# Processing Record 34 of Set 5 | codrington
# Processing Record 35 of Set 5 | chapais
# Processing Record 36 of Set 5 | alice springs
# Processing Record 37 of Set 5 | simao
# Processing Record 38 of Set 5 | llanes
# Processing Record 39 of Set 5 | solnechnyy
# Processing Record 40 of Set 5 | aykhal
# Processing Record 41 of Set 5 | takoradi
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | norman wells
# Processing Record 45 of Set 5 | kunming
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | rokytne
# Processing Record 48 of Set 5 | toora-khem
# Processing Record 49 of Set 5 | tela
# Processing Record 50 of Set 5 | mangrol
# Processing Record 1 of Set 6 | anshun
# Processing Record 2 of Set 6 | zaysan
# Processing Record 3 of Set 6 | verkhoyansk
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | nokaneng
# Processing Record 8 of Set 6 | khatanga
# Processing Record 9 of Set 6 | redhakhol
# City not found. Skipping...
# Processing Record 10 of Set 6 | okhotsk
# Processing Record 11 of Set 6 | mingoyo
# Processing Record 12 of Set 6 | thinadhoo
# Processing Record 13 of Set 6 | longyearbyen
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | omboue
# Processing Record 16 of Set 6 | candawaga
# City not found. Skipping...
# Processing Record 17 of Set 6 | kifri
# Processing Record 18 of Set 6 | constitucion
# Processing Record 19 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | port lincoln
# Processing Record 23 of Set 6 | strezhevoy
# Processing Record 24 of Set 6 | kudahuvadhoo
# Processing Record 25 of Set 6 | klaksvik
# Processing Record 26 of Set 6 | half moon bay
# Processing Record 27 of Set 6 | provideniya
# Processing Record 28 of Set 6 | shitanjing
# Processing Record 29 of Set 6 | chuy
# Processing Record 30 of Set 6 | denizli
# Processing Record 31 of Set 6 | ifanadiana
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | along
# Processing Record 34 of Set 6 | saint-esteve
# Processing Record 35 of Set 6 | kupino
# Processing Record 36 of Set 6 | vanavara
# Processing Record 37 of Set 6 | kurilsk
# Processing Record 38 of Set 6 | ostrow wielkopolski
# Processing Record 39 of Set 6 | vestmanna
# Processing Record 40 of Set 6 | salvador
# Processing Record 41 of Set 6 | fort-shevchenko
# Processing Record 42 of Set 6 | gainesville
# Processing Record 43 of Set 6 | atar
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | batagay
# Processing Record 46 of Set 6 | alofi
# Processing Record 47 of Set 6 | druzhinino
# Processing Record 48 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 6 | kenai
# Processing Record 50 of Set 6 | sokoni
# Processing Record 1 of Set 7 | yanggu
# Processing Record 2 of Set 7 | wilmington
# Processing Record 3 of Set 7 | maniitsoq
# Processing Record 4 of Set 7 | prizren
# Processing Record 5 of Set 7 | kasangulu
# Processing Record 6 of Set 7 | cayenne
# Processing Record 7 of Set 7 | palafrugell
# Processing Record 8 of Set 7 | cockburn town
# Processing Record 9 of Set 7 | inirida
# Processing Record 10 of Set 7 | arraial do cabo
# Processing Record 11 of Set 7 | tamandare
# Processing Record 12 of Set 7 | khyriv
# Processing Record 13 of Set 7 | grand gaube
# Processing Record 14 of Set 7 | yar-sale
# Processing Record 15 of Set 7 | rawson
# Processing Record 16 of Set 7 | ontario
# Processing Record 17 of Set 7 | praia da vitoria
# Processing Record 18 of Set 7 | padang
# Processing Record 19 of Set 7 | behbahan
# Processing Record 20 of Set 7 | bedele
# Processing Record 21 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 7 | port moresby
# Processing Record 23 of Set 7 | eydhafushi
# Processing Record 24 of Set 7 | rawlins
# Processing Record 25 of Set 7 | kjollefjord
# Processing Record 26 of Set 7 | ust-nera
# Processing Record 27 of Set 7 | masuguru
# Processing Record 28 of Set 7 | gawler
# Processing Record 29 of Set 7 | pundaguitan
# Processing Record 30 of Set 7 | dalvik
# Processing Record 31 of Set 7 | pochutla
# Processing Record 32 of Set 7 | baghdad
# Processing Record 33 of Set 7 | port-gentil
# Processing Record 34 of Set 7 | eagle
# Processing Record 35 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint-francois
# Processing Record 37 of Set 7 | cherskiy
# Processing Record 38 of Set 7 | george
# Processing Record 39 of Set 7 | guerrero negro
# Processing Record 40 of Set 7 | ancud
# Processing Record 41 of Set 7 | aldan
# Processing Record 42 of Set 7 | palmer
# Processing Record 43 of Set 7 | hasanabad
# Processing Record 44 of Set 7 | raudeberg
# Processing Record 45 of Set 7 | apatou
# Processing Record 46 of Set 7 | muli
# Processing Record 47 of Set 7 | raduzhnyy
# Processing Record 48 of Set 7 | tieling
# Processing Record 49 of Set 7 | nome
# Processing Record 50 of Set 7 | coxim
# Processing Record 1 of Set 8 | nabire
# Processing Record 2 of Set 8 | kirakira
# Processing Record 3 of Set 8 | arawa
# Processing Record 4 of Set 8 | asilah
# Processing Record 5 of Set 8 | vitry-le-francois
# Processing Record 6 of Set 8 | mori
# Processing Record 7 of Set 8 | nanortalik
# Processing Record 8 of Set 8 | kamenka
# Processing Record 9 of Set 8 | izumo
# Processing Record 10 of Set 8 | awash
# Processing Record 11 of Set 8 | berlevag
# Processing Record 12 of Set 8 | bad neuenahr-ahrweiler
# Processing Record 13 of Set 8 | dir
# Processing Record 14 of Set 8 | ampanihy
# Processing Record 15 of Set 8 | sioux lookout
# Processing Record 16 of Set 8 | panzhihua
# Processing Record 17 of Set 8 | manakara
# Processing Record 18 of Set 8 | amapa
# Processing Record 19 of Set 8 | maldonado
# Processing Record 20 of Set 8 | bundaberg
# Processing Record 21 of Set 8 | coracora
# Processing Record 22 of Set 8 | lebu
# Processing Record 23 of Set 8 | pilar
# Processing Record 24 of Set 8 | santa clara
# Processing Record 25 of Set 8 | bubaque
# Processing Record 26 of Set 8 | batticaloa
# Processing Record 27 of Set 8 | aksarka
# Processing Record 28 of Set 8 | coruripe
# Processing Record 29 of Set 8 | port hardy
# Processing Record 30 of Set 8 | canandaigua
# Processing Record 31 of Set 8 | sars
# Processing Record 32 of Set 8 | katangli
# Processing Record 33 of Set 8 | comodoro rivadavia
# Processing Record 34 of Set 8 | alexandria
# Processing Record 35 of Set 8 | fort nelson
# Processing Record 36 of Set 8 | burgeo
# Processing Record 37 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 8 | akonolinga
# Processing Record 39 of Set 8 | ostrovnoy
# Processing Record 40 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 8 | kangaatsiaq
# Processing Record 42 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 8 | mto wa mbu
# Processing Record 44 of Set 8 | port macquarie
# Processing Record 45 of Set 8 | khuzhir
# Processing Record 46 of Set 8 | kaa-khem
# Processing Record 47 of Set 8 | tofield
# Processing Record 48 of Set 8 | pangai
# Processing Record 49 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 8 | jiexiu
# Processing Record 1 of Set 9 | dzerzhinsk
# Processing Record 2 of Set 9 | cabo san lucas
# Processing Record 3 of Set 9 | landau
# Processing Record 4 of Set 9 | acaponeta
# Processing Record 5 of Set 9 | isangel
# Processing Record 6 of Set 9 | doha
# Processing Record 7 of Set 9 | atyrau
# Processing Record 8 of Set 9 | kawalu
# Processing Record 9 of Set 9 | murgab
# Processing Record 10 of Set 9 | santa isabel
# Processing Record 11 of Set 9 | medvezhyegorsk
# Processing Record 12 of Set 9 | korla
# Processing Record 13 of Set 9 | kingman
# Processing Record 14 of Set 9 | zabol
# Processing Record 15 of Set 9 | talavera
# Processing Record 16 of Set 9 | coquimbo
# Processing Record 17 of Set 9 | nauta
# Processing Record 18 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 9 | boca do acre
# Processing Record 20 of Set 9 | viedma
# Processing Record 21 of Set 9 | gull lake
# Processing Record 22 of Set 9 | tecoanapa
# Processing Record 23 of Set 9 | chalan
# Processing Record 24 of Set 9 | xichang
# Processing Record 25 of Set 9 | boromo
# Processing Record 26 of Set 9 | winslow
# Processing Record 27 of Set 9 | revelstoke
# Processing Record 28 of Set 9 | kargat
# Processing Record 29 of Set 9 | celestun
# Processing Record 30 of Set 9 | surany
# Processing Record 31 of Set 9 | auki
# Processing Record 32 of Set 9 | nevel
# Processing Record 33 of Set 9 | dalbandin
# Processing Record 34 of Set 9 | abashiri
# Processing Record 35 of Set 9 | kargasok
# Processing Record 36 of Set 9 | batemans bay
# Processing Record 37 of Set 9 | beruwala
# Processing Record 38 of Set 9 | moron
# Processing Record 39 of Set 9 | mehamn
# Processing Record 40 of Set 9 | pringsewu
# Processing Record 41 of Set 9 | abalak
# Processing Record 42 of Set 9 | susangerd
# Processing Record 43 of Set 9 | daru
# Processing Record 44 of Set 9 | iquique
# Processing Record 45 of Set 9 | broken hill
# Processing Record 46 of Set 9 | emerald
# Processing Record 47 of Set 9 | pouembout
# Processing Record 48 of Set 9 | lake havasu city
# Processing Record 49 of Set 9 | walvis bay
# Processing Record 50 of Set 9 | christchurch
# Processing Record 1 of Set 10 | gumdag
# Processing Record 2 of Set 10 | oriximina
# Processing Record 3 of Set 10 | gat
# Processing Record 4 of Set 10 | dayong
# Processing Record 5 of Set 10 | kichera
# Processing Record 6 of Set 10 | quatre cocos
# Processing Record 7 of Set 10 | talara
# Processing Record 8 of Set 10 | shimoda
# Processing Record 9 of Set 10 | zenzeli
# Processing Record 10 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 10 | tamiahua
# Processing Record 12 of Set 10 | havoysund
# Processing Record 13 of Set 10 | sola
# Processing Record 14 of Set 10 | meulaboh
# Processing Record 15 of Set 10 | umm lajj
# Processing Record 16 of Set 10 | sao sebastiao
# Processing Record 17 of Set 10 | hobyo
# Processing Record 18 of Set 10 | rock sound
# Processing Record 19 of Set 10 | richards bay
# Processing Record 20 of Set 10 | ballina
# Processing Record 21 of Set 10 | praya
# Processing Record 22 of Set 10 | kungurtug
# Processing Record 23 of Set 10 | dalianwan
# Processing Record 24 of Set 10 | eau claire
# Processing Record 25 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 10 | mayo
# Processing Record 27 of Set 10 | kismayo
# Processing Record 28 of Set 10 | san policarpo
# Processing Record 29 of Set 10 | vila velha
# Processing Record 30 of Set 10 | waipawa
# Processing Record 31 of Set 10 | taiyuan
# Processing Record 32 of Set 10 | bashtanka
# Processing Record 33 of Set 10 | lompoc
# Processing Record 34 of Set 10 | charapan
# Processing Record 35 of Set 10 | trairi
# Processing Record 36 of Set 10 | tapes
# Processing Record 37 of Set 10 | graaff-reinet
# Processing Record 38 of Set 10 | diego de almagro
# Processing Record 39 of Set 10 | kalabo
# Processing Record 40 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | tilichiki
# Processing Record 42 of Set 10 | brisbane
# Processing Record 43 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 10 | chabahar
# Processing Record 45 of Set 10 | methoni
# Processing Record 46 of Set 10 | mandalgovi
# Processing Record 47 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 10 | katsuura
# Processing Record 49 of Set 10 | ugoofaaru
# Processing Record 50 of Set 10 | novaya bryan
# Processing Record 1 of Set 11 | zhuhai
# Processing Record 2 of Set 11 | negara
# Processing Record 3 of Set 11 | vasto
# Processing Record 4 of Set 11 | johi
# Processing Record 5 of Set 11 | houma
# Processing Record 6 of Set 11 | bodden town
# Processing Record 7 of Set 11 | makinsk
# Processing Record 8 of Set 11 | carnarvon
# Processing Record 9 of Set 11 | beringovskiy
# Processing Record 10 of Set 11 | khalandritsa
# City not found. Skipping...
# Processing Record 11 of Set 11 | tirlyanskiy
# Processing Record 12 of Set 11 | santa cruz cabralia
# Processing Record 13 of Set 11 | soyo
# Processing Record 14 of Set 11 | bocaiuva
# Processing Record 15 of Set 11 | hofn
# Processing Record 16 of Set 11 | kankan
# Processing Record 17 of Set 11 | grand-santi
# Processing Record 18 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 11 | sawtell
# Processing Record 20 of Set 11 | sorsk
# Processing Record 21 of Set 11 | panguna
# Processing Record 22 of Set 11 | nong kung si
# Processing Record 23 of Set 11 | high level
# Processing Record 24 of Set 11 | kourou
# Processing Record 25 of Set 11 | saint george
# Processing Record 26 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 11 | tornio
# Processing Record 28 of Set 11 | ghanzi
# Processing Record 29 of Set 11 | aljezur
# Processing Record 30 of Set 11 | chitral
# Processing Record 31 of Set 11 | altamira
# Processing Record 32 of Set 11 | pacific grove
# Processing Record 33 of Set 11 | najran
# Processing Record 34 of Set 11 | rio brilhante
# Processing Record 35 of Set 11 | lukulu
# Processing Record 36 of Set 11 | kavaratti
# Processing Record 37 of Set 11 | pedernales
# Processing Record 38 of Set 11 | vizinga
# Processing Record 39 of Set 11 | rio grande
# Processing Record 40 of Set 11 | te anau
# Processing Record 41 of Set 11 | inuvik
# Processing Record 42 of Set 11 | mackenzie
# Processing Record 43 of Set 11 | shahrud
# Processing Record 44 of Set 11 | miles city
# Processing Record 45 of Set 11 | zeya
# Processing Record 46 of Set 11 | charlottetown
# Processing Record 47 of Set 11 | portlethen
# Processing Record 48 of Set 11 | kyshtovka
# Processing Record 49 of Set 11 | naze
# Processing Record 50 of Set 11 | aden
# Processing Record 1 of Set 12 | san miguel
# Processing Record 2 of Set 12 | mareeba
# Processing Record 3 of Set 12 | morros
# Processing Record 4 of Set 12 | ola
# Processing Record 5 of Set 12 | port shepstone
# Processing Record 6 of Set 12 | saint stephen
# Processing Record 7 of Set 12 | saldanha
# Processing Record 8 of Set 12 | goundam
# Processing Record 9 of Set 12 | seljord
# Processing Record 10 of Set 12 | lorengau
# Processing Record 11 of Set 12 | moose factory
# Processing Record 12 of Set 12 | wanaka
# Processing Record 13 of Set 12 | santa maria
# Processing Record 14 of Set 12 | torata
# Processing Record 15 of Set 12 | iberia
# Processing Record 16 of Set 12 | bilibino
# Processing Record 17 of Set 12 | spetsai
# City not found. Skipping...
# Processing Record 18 of Set 12 | nuuk
# Processing Record 19 of Set 12 | sovetskoye
# Processing Record 20 of Set 12 | dillingen
# Processing Record 21 of Set 12 | butajira
# Processing Record 22 of Set 12 | portland
# Processing Record 23 of Set 12 | chimbote
# Processing Record 24 of Set 12 | aklavik
# Processing Record 25 of Set 12 | astipalaia
# City not found. Skipping...
# Processing Record 26 of Set 12 | yanam
# Processing Record 27 of Set 12 | wukari
# Processing Record 28 of Set 12 | hamada
# Processing Record 29 of Set 12 | lima
# Processing Record 30 of Set 12 | terney
# Processing Record 31 of Set 12 | nantucket
# Processing Record 32 of Set 12 | tukrah
# Processing Record 33 of Set 12 | pulandian
# Processing Record 34 of Set 12 | san andres
# Processing Record 35 of Set 12 | mporokoso
# Processing Record 36 of Set 12 | filadelfia
# Processing Record 37 of Set 12 | bani walid
# Processing Record 38 of Set 12 | santa rosa
# Processing Record 39 of Set 12 | tiznit
# Processing Record 40 of Set 12 | vendome
# Processing Record 41 of Set 12 | aquiraz
# Processing Record 42 of Set 12 | labuhan
# Processing Record 43 of Set 12 | yima
# Processing Record 44 of Set 12 | dhidhdhoo
# Processing Record 45 of Set 12 | kabanjahe
# Processing Record 46 of Set 12 | maribong
# Processing Record 47 of Set 12 | trelew
# Processing Record 48 of Set 12 | opuwo
# Processing Record 49 of Set 12 | west wendover
# Processing Record 50 of Set 12 | salto
# Processing Record 1 of Set 13 | staryy urukh
# Processing Record 2 of Set 13 | ukholovo
# Processing Record 3 of Set 13 | kandrian
# Processing Record 4 of Set 13 | amazar
# Processing Record 5 of Set 13 | bocas del toro
# Processing Record 6 of Set 13 | olafsvik
# Processing Record 7 of Set 13 | rawicz
# Processing Record 8 of Set 13 | dunedin
# Processing Record 9 of Set 13 | santa sofia
# Processing Record 10 of Set 13 | ipixuna
# Processing Record 11 of Set 13 | paamiut
# Processing Record 12 of Set 13 | gravdal
# Processing Record 13 of Set 13 | togur
# Processing Record 14 of Set 13 | skelleftea
# Processing Record 15 of Set 13 | kupang
# Processing Record 16 of Set 13 | progreso
# Processing Record 17 of Set 13 | mangai
# Processing Record 18 of Set 13 | agde
# Processing Record 19 of Set 13 | gejiu
# Processing Record 20 of Set 13 | sulangan
# Processing Record 21 of Set 13 | vostok
# Processing Record 22 of Set 13 | pokhara
# Processing Record 23 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 13 | derzhavinsk
# Processing Record 25 of Set 13 | turka
# Processing Record 26 of Set 13 | dekar
# Processing Record 27 of Set 13 | bayburt
# Processing Record 28 of Set 13 | hay river
# Processing Record 29 of Set 13 | san rafael
# Processing Record 30 of Set 13 | nioro
# Processing Record 31 of Set 13 | pemba
# Processing Record 32 of Set 13 | tucurui
# Processing Record 33 of Set 13 | dukat
# Processing Record 34 of Set 13 | hastings
# Processing Record 35 of Set 13 | morehead
# Processing Record 36 of Set 13 | maine-soroa
# Processing Record 37 of Set 13 | panama city
# Processing Record 38 of Set 13 | singkang
# Processing Record 39 of Set 13 | ixtapa
# Processing Record 40 of Set 13 | decin
# Processing Record 41 of Set 13 | safranbolu
# Processing Record 42 of Set 13 | linares
# Processing Record 43 of Set 13 | rocha
# Processing Record 44 of Set 13 | belmonte
# Processing Record 45 of Set 13 | santiago de cao
# Processing Record 46 of Set 13 | boulsa
# Processing Record 47 of Set 13 | katherine
# Processing Record 48 of Set 13 | san roque
# Processing Record 49 of Set 13 | kopyevo
# City not found. Skipping...
# Processing Record 50 of Set 13 | iguatu
# Processing Record 1 of Set 14 | gamba
# Processing Record 2 of Set 14 | faya
# Processing Record 3 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 4 of Set 14 | djenne
# Processing Record 5 of Set 14 | konstantinovka
# Processing Record 6 of Set 14 | akdepe
# Processing Record 7 of Set 14 | sistranda
# Processing Record 8 of Set 14 | luebo
# Processing Record 9 of Set 14 | oranjestad
# Processing Record 10 of Set 14 | khani
# Processing Record 11 of Set 14 | danielskuil
# Processing Record 12 of Set 14 | cicero dantas
# Processing Record 13 of Set 14 | kamen-rybolov
# Processing Record 14 of Set 14 | calvinia
# Processing Record 15 of Set 14 | sorong
# Processing Record 16 of Set 14 | husavik
# Processing Record 17 of Set 14 | chara
# Processing Record 18 of Set 14 | kusti
# Processing Record 19 of Set 14 | robertsport
# Processing Record 20 of Set 14 | belaya gora
# Processing Record 21 of Set 14 | antofagasta
# Processing Record 22 of Set 14 | burnie
# Processing Record 23 of Set 14 | unhel
# Processing Record 24 of Set 14 | pampa
# Processing Record 25 of Set 14 | lumsden
# Processing Record 26 of Set 14 | nkhata bay
# Processing Record 27 of Set 14 | sembe
# Processing Record 28 of Set 14 | esmeraldas
# Processing Record 29 of Set 14 | ponta delgada
# Processing Record 30 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 14 | ponta pora
# Processing Record 32 of Set 14 | santa isabel do rio negro
# Processing Record 33 of Set 14 | blankenberge
# Processing Record 34 of Set 14 | bangangte
# Processing Record 35 of Set 14 | agirish
# Processing Record 36 of Set 14 | mbandaka
# Processing Record 37 of Set 14 | hambantota
# Processing Record 38 of Set 14 | maragogi
# Processing Record 39 of Set 14 | eyl
# Processing Record 40 of Set 14 | mul
# Processing Record 41 of Set 14 | villa del rosario
# Processing Record 42 of Set 14 | palana
# Processing Record 43 of Set 14 | humaita
# Processing Record 44 of Set 14 | beira
# Processing Record 45 of Set 14 | dirba
# Processing Record 46 of Set 14 | glace bay
# Processing Record 47 of Set 14 | bugulma
# Processing Record 48 of Set 14 | la ronge
# Processing Record 49 of Set 14 | whitefish
# Processing Record 50 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 15 | ewa beach
# Processing Record 2 of Set 15 | vetlanda
# Processing Record 3 of Set 15 | jaroslaw
# Processing Record 4 of Set 15 | karratha
# Processing Record 5 of Set 15 | krasnoselkup
# Processing Record 6 of Set 15 | dali
# Processing Record 7 of Set 15 | natal
# Processing Record 8 of Set 15 | padre bernardo
# Processing Record 9 of Set 15 | redwater
# Processing Record 10 of Set 15 | mendi
# Processing Record 11 of Set 15 | nueva guinea
# Processing Record 12 of Set 15 | lockport
# Processing Record 13 of Set 15 | loikaw
# Processing Record 14 of Set 15 | ikot ekpene
# Processing Record 15 of Set 15 | salinas
# Processing Record 16 of Set 15 | alta floresta
# Processing Record 17 of Set 15 | port augusta
# Processing Record 18 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 15 | makanya
# Processing Record 20 of Set 15 | cairns
# Processing Record 21 of Set 15 | kalmunai
# Processing Record 22 of Set 15 | chulman
# Processing Record 23 of Set 15 | catamarca
# Processing Record 24 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 25 of Set 15 | banikoara
# Processing Record 26 of Set 15 | poltavka
# Processing Record 27 of Set 15 | naryan-mar
# Processing Record 28 of Set 15 | trat
# Processing Record 29 of Set 15 | castletown
# Processing Record 30 of Set 15 | aswan
# Processing Record 31 of Set 15 | bowling green
# Processing Record 32 of Set 15 | jeremoabo
# Processing Record 33 of Set 15 | jiaojiang
# Processing Record 34 of Set 15 | baijiantan
# Processing Record 35 of Set 15 | san vicente de canete
# Processing Record 36 of Set 15 | guarapari
# Processing Record 37 of Set 15 | boa vista
# Processing Record 38 of Set 15 | matara
# Processing Record 39 of Set 15 | north bend
# Processing Record 40 of Set 15 | whitecourt
# Processing Record 41 of Set 15 | kajaani
# Processing Record 42 of Set 15 | berbera
# Processing Record 43 of Set 15 | santiago
# Processing Record 44 of Set 15 | goya
# Processing Record 45 of Set 15 | shanhetun
# Processing Record 46 of Set 15 | dingle
# Processing Record 47 of Set 15 | pahrump
# Processing Record 48 of Set 15 | killin
# Processing Record 49 of Set 15 | yarovoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333     70.09        68          13
# 1    Butaritari   3.0707  172.7902     81.88        78          73
# 2      Cidreira -30.1811  -50.2056     74.46        83           0
# 3      Souillac -20.5167   57.5167     75.58        94          40
# 4      Chumikan  54.7183  135.3150      8.98        92         100
# 5  Punta Arenas -53.1500  -70.9167     57.31        72          75
# 6        Eureka  40.8021 -124.1637     65.68        72         100
# 7          Lata  40.1629   -8.3327     49.71        94         100
# 8       Ushuaia -54.8000  -68.3000     49.66       100         100
# 9   San Joaquin  37.9333 -121.3011     73.63        44           0
#
#    Wind Speed Country                 Date   Current Description
# 0        8.86      AU  2022-02-12 01:16:52            few clouds
# 1       15.43      KI  2022-02-12 01:17:38            light rain
# 2       20.31      BR  2022-02-12 01:20:57             clear sky
# 3        3.44      MU  2022-02-12 01:20:57      scattered clouds
# 4        4.41      RU  2022-02-12 01:20:57            light snow
# 5       28.77      CL  2022-02-12 01:20:58         broken clouds
# 6        1.01      US  2022-02-12 01:20:58       overcast clouds
# 7        1.34      PT  2022-02-12 01:20:59       overcast clouds
# 8        6.91      AR  2022-02-12 01:20:59  heavy intensity rain
# 9        0.00      US  2022-02-12 01:20:59             clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
